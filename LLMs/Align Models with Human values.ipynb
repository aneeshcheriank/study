# %% [markdown]
# - Generatie AI project Lifecycle
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - LLMs problems on completion
#     - Toxic language
#         - model gives an o/p that is not what you are looking for
#         - give some incorrect advice
#         - give toxic completion
#         - example: give an answer to how to hack neighbours wifi
#         - the completion shoud be
#             - helpful, honest, harmless (HHH)
#     - Aggressive responses
#     - provide dangerous information

# %% [markdown]
# ## Using feedback from Humens
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - a popular technique to finetune the model
#     - Reinforcemnt learning from human feedback (RLHF)
#     - LLM -> Reinfocement learning with human feedback -> Human aligned LLM
#         - maximize the helpfulness and relevance
#         - minimize the harm
#         - avoid dangerous topics

# %% [markdown]
# ### Reinfocement Learning
# - agent
# - environment
# - agent improves its action based on its reward/penalities it gained from the actions it taken
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Reinforcement learning: fine-tuning LLMs
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Obtaining feedback from humans
# - Stesps
#     - select a model
#     - prompt data set -> generate completion
#     - feedback on completions (human feedback)
#         - criterian for the human to give feedback on
#         - ask person to give feedback
#         - give most helpful to least helpful feedback
#         ![image.png](attachment:image.png)
#     - assign more human labelers
#         - quality of the data (ensuring)

# %% [markdown]
# ![image.png](attachment:image.png)
# - overall task (first instruction)
# - how to complete the task
# - what to do if there is a tie
# - what to do if there is a completion that not making any sense

# %% [markdown]
# ### Prepare labelled data for trainnig
# - convert ranking into pairwise training data for the reward model
# - for a prompt there are 3 completions
# - we have to choose pairs from these 3 -> 3c2 choices
# - then need to define rewards -> 0 for not prefered response and 1 for prefered response in the pair
# - re order the rank so the prefered option comes first
# ![image.png](attachment:image.png)
