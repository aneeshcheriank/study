# %% [markdown]
# ## Lecture Notes
#
# ### ReAct (Reason + Act)
# ![image.png](attachment:30efdd7e-2482-447d-8126-95c3f4072612.png)
#
# - Process
#   - LLM thinks about what to do
#   - decide on what action to take
#   - the action is taken in an environment -> an observation is returned
#   - the LLM thinks with that observation -> thus repeat the process
